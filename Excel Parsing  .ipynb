# %%
import pandas as pd
from pandas import DataFrame
import xlrd

# %%
xls_file = pd.ExcelFile('SOWC 2014 Stat Tables_Table 9.xlsx')

# %%
table = xls_file.parse('Table 9 ')

# data = pd.read_csv('test.csv', sep='|', header=0, skiprows=10, nrows=10)
# By giving the function the integer 10, you're just skipping the first 10 lines.
# To keep the first row 0 (as the header) and then skip to row 10, you could write:
# pd.read_csv('test.csv', sep='|', skiprows=range(1, 10))

# %%
table.head()
# Out:
#     TABLE 9. CHILD PROTECTION                         Unnamed: 1  \
# NaN                       NaN  TABLEAU 9. PROTECTION DE L’ENFANT
# NaN                       NaN                                NaN
# NaN                       NaN                                NaN
# NaN       Countries and areas                                NaN
# NaN                       NaN                                NaN
#
#                        Unnamed: 2                     Unnamed: 3 Unnamed: 4  \
# NaN                           NaN                            NaN        NaN
# NaN  TABLA 9. PROTECCIÓN INFANTIL                            NaN        NaN
# NaN                           NaN                            NaN        NaN
# NaN                           NaN  Child labour (%)+\n2005–2012*        NaN
# NaN                           NaN                            NaN        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# NaN        NaN        NaN        NaN        NaN
# ...

# %%
table = xls_file.parse('Table 9 ', skiprows=range(1, 14))

# %%
#data = pd.read_csv('test.csv', sep='|', header=0, skiprows=10, nrows=10)
#By giving the function the integer 10, you're just skipping the first 10 lines.

#To keep the first row 0 (as the header) and then skip to row 10, you could write:
#pd.read_csv('test.csv', sep='|', skiprows=range(1, 10))

# %%
table.head()
# Out:
#     TABLE 9. CHILD PROTECTION   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# NaN               Afghanistan  Afghanistan  Afganistán       10.3        NaN
# NaN                   Albania      Albanie     Albania         12
# NaN                   Algeria      Algérie     Argelia        4.7          y
# NaN                   Andorra      Andorre     Andorra         –
# NaN                    Angola       Angola      Angola       23.5          x
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      \
# NaN         11        NaN        9.6        NaN         15     ...
# NaN       14.4                   9.4                   0.2     ...
# NaN        5.5          y        3.9          y        0.1     ...
# NaN          –                     –                     –     ...
# NaN       22.1          x       24.8          x          –     ...
#
#     Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38  \
# ...

# %%
table.dropna(axis=1, how='all'); #does not consider the 1 col as all Nan
table.head()
# Out:
#     TABLE 9. CHILD PROTECTION   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# NaN               Afghanistan  Afghanistan  Afganistán       10.3        NaN
# NaN                   Albania      Albanie     Albania         12
# NaN                   Algeria      Algérie     Argelia        4.7          y
# NaN                   Andorra      Andorre     Andorra         –
# NaN                    Angola       Angola      Angola       23.5          x
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      \
# NaN         11        NaN        9.6        NaN         15     ...
# NaN       14.4                   9.4                   0.2     ...
# NaN        5.5          y        3.9          y        0.1     ...
# NaN          –                     –                     –     ...
# NaN       22.1          x       24.8          x          –     ...
#
#     Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38  \
# ...

# %%
#df.drop(df.columns[[0,1,3]], axis=1, inplace=True)

# %%
table.drop(table.columns[[range(13,40)]], axis=1, inplace=True)# del unneeded col

# %%
table.head()
# Out:
#     TABLE 9. CHILD PROTECTION   Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# NaN               Afghanistan  Afghanistan  Afganistán       10.3        NaN
# NaN                   Albania      Albanie     Albania         12
# NaN                   Algeria      Algérie     Argelia        4.7          y
# NaN                   Andorra      Andorre     Andorra         –
# NaN                    Angola       Angola      Angola       23.5          x
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# NaN         11        NaN        9.6        NaN         15         NaN
# NaN       14.4                   9.4                   0.2         NaN
# NaN        5.5          y        3.9          y        0.1         NaN
# NaN          –                     –                     –         NaN
# NaN       22.1          x       24.8          x          –         NaN
#
#     Unnamed: 11 Unnamed: 12  Unnamed: 40  Unnamed: 41  Unnamed: 42
# ...

# %%
tab2=table.set_index(['TABLE 9. CHILD PROTECTION']);#use as index one of the col
tab2.head()
# Out:
#                             Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# TABLE 9. CHILD PROTECTION
# Afghanistan                Afghanistan  Afganistán       10.3        NaN
# Albania                        Albanie     Albania         12
# Algeria                        Algérie     Argelia        4.7          y
# Andorra                        Andorre     Andorra         –
# Angola                          Angola      Angola       23.5          x
#
#                           Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# TABLE 9. CHILD PROTECTION
# Afghanistan                       11        NaN        9.6        NaN
# Albania                         14.4                   9.4
# Algeria                          5.5          y        3.9          y
# Andorra                            –                     –
# Angola                          22.1          x       24.8          x
#
#                           Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
tab2.columns = ['French', 'spanish', 'ch_lab_tot', '', 'ch_lab_m', '', 'ch_lab_f', '', 'ch_mar_15', '', 'ch_mar_18', '', '', '', '']

# %%
tab2.head()
# Out:
#                                 French     spanish ch_lab_tot      ch_lab_m  \
# TABLE 9. CHILD PROTECTION
# Afghanistan                Afghanistan  Afganistán       10.3  NaN       11
# Albania                        Albanie     Albania         12          14.4
# Algeria                        Algérie     Argelia        4.7    y      5.5
# Andorra                        Andorre     Andorra         –              –
# Angola                          Angola      Angola       23.5    x     22.1
#
#                                ch_lab_f      ch_mar_15      ch_mar_18       \
# TABLE 9. CHILD PROTECTION
# Afghanistan                NaN      9.6  NaN        15  NaN      40.4  NaN
# Albania                             9.4            0.2  NaN       9.6  NaN
# Algeria                      y      3.9    y       0.1  NaN       1.8  NaN
# Andorra                               –              –  NaN         –  NaN
# Angola                       x     24.8    x         –  NaN         –  NaN
#
#
# ...

# %%
tab2.dropna(axis=1, how='all'); #doesnt recognises the last columns as all Nan
tab2.head()
# Out:
#                                 French     spanish ch_lab_tot      ch_lab_m  \
# TABLE 9. CHILD PROTECTION
# Afghanistan                Afghanistan  Afganistán       10.3  NaN       11
# Albania                        Albanie     Albania         12          14.4
# Algeria                        Algérie     Argelia        4.7    y      5.5
# Andorra                        Andorre     Andorra         –              –
# Angola                          Angola      Angola       23.5    x     22.1
#
#                                ch_lab_f      ch_mar_15      ch_mar_18       \
# TABLE 9. CHILD PROTECTION
# Afghanistan                NaN      9.6  NaN        15  NaN      40.4  NaN
# Albania                             9.4            0.2  NaN       9.6  NaN
# Algeria                      y      3.9    y       0.1  NaN       1.8  NaN
# Andorra                               –              –  NaN         –  NaN
# Angola                       x     24.8    x         –  NaN         –  NaN
#
#
# ...

# %%
tab2.describe()
# Out:
# C:\Users\Olga and Jean\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#
# count   187  187  187    6    7  0.0  0.0  0.0
# unique    6    6    5    2    2  NaN  NaN  NaN
# top                      x    x  NaN  NaN  NaN
# freq     88   89  144    4    5  NaN  NaN  NaN
# mean    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# std     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# min     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25%     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 50%     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75%     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# max     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Index of the row with the highest value in the 'ch_lab_tot' column
tab2['ch_lab_tot'].idxmax()
